# %%
import pandas as pd
df=pd.DataFrame({
    'milage':[69000,35000,57000,22500,46000,59000,52000,72000,91000,67000,83000,79000,59000,58780,82450,25400,28000,69000,87600,52000],
    'Age':[6,3,5,2,4,5,5,6,8,6,7,7,5,4,7,3,2,5,8,5],
    'sell price':[18000,34000,26100,40000,31500,26750,32000,19300,12000,22000,18700,19500,26000,27500,19400,35000,35500,19700,12800,28200]
})
df
# Out:
#     milage  Age  sell price
# 0    69000    6       18000
# 1    35000    3       34000
# 2    57000    5       26100
# 3    22500    2       40000
# 4    46000    4       31500
# 5    59000    5       26750
# 6    52000    5       32000
# 7    72000    6       19300
# 8    91000    8       12000
# 9    67000    6       22000
# 10   83000    7       18700
# 11   79000    7       19500
# 12   59000    5       26000
# 13   58780    4       27500
# 14   82450    7       19400
# 15   25400    3       35000
# 16   28000    2       35500
# 17   69000    5       19700
# 18   87600    8       12800
# 19   52000    5       28200

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.scatter(df['milage'],df['sell price'])

# %%
plt.scatter(df['Age'],df['sell price'])

# %%
x=df[['milage','Age']]

y=df['sell price']
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: sell price, dtype: int64

# %%
x
# Out:
#     milage  Age
# 0    69000    6
# 1    35000    3
# 2    57000    5
# 3    22500    2
# 4    46000    4
# 5    59000    5
# 6    52000    5
# 7    72000    6
# 8    91000    8
# 9    67000    6
# 10   83000    7
# 11   79000    7
# 12   59000    5
# 13   58780    4
# 14   82450    7
# 15   25400    3
# 16   28000    2
# 17   69000    5
# 18   87600    8
# 19   52000    5

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
len(x_train)
# Out:
# 16

# %%
len(y_train)
len(x_test)
# Out:
# 4

# %%
x_train
# Out:
#     milage  Age
# 3    22500    2
# 5    59000    5
# 13   58780    4
# 14   82450    7
# 1    35000    3
# 8    91000    8
# 6    52000    5
# 0    69000    6
# 18   87600    8
# 17   69000    5
# 15   25400    3
# 2    57000    5
# 4    46000    4
# 19   52000    5
# 7    72000    6
# 9    67000    6

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.predict(x_test)
# Out:
# array([37729.18796353, 17380.2443852 , 16052.63937563, 25387.06131557])

# %%
y_test
# Out:
# 16    35500
# 11    19500
# 10    18700
# 12    26000
# Name: sell price, dtype: int64

# %%
reg.score(x_test,y_test)
# Out:
# 0.9070095080541534
